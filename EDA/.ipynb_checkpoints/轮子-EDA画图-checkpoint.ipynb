# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#数据初探-nbr=number" data-toc-modified-id="数据初探-nbr=number-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>数据初探 nbr=number</a></span><ul class="toc-item"><li><span><a href="#train" data-toc-modified-id="train-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>train</a></span></li><li><span><a href="#test" data-toc-modified-id="test-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>test</a></span></li></ul></li><li><span><a href="#单变量分析（单变量的value_counts问题）" data-toc-modified-id="单变量分析（单变量的value_counts问题）-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>单变量分析（单变量的value_counts问题）</a></span><ul class="toc-item"><li><span><a href="#value_counts图countplot" data-toc-modified-id="value_counts图countplot-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>value_counts图countplot</a></span></li><li><span><a href="#均匀显示刻度" data-toc-modified-id="均匀显示刻度-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>均匀显示刻度</a></span></li><li><span><a href="#value_counts图countplot" data-toc-modified-id="value_counts图countplot-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>value_counts图countplot</a></span></li><li><span><a href="#barplot" data-toc-modified-id="barplot-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>barplot</a></span></li></ul></li><li><span><a href="#多变量分析" data-toc-modified-id="多变量分析-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>多变量分析</a></span><ul class="toc-item"><li><span><a href="#countplot+hue+subplot" data-toc-modified-id="countplot+hue+subplot-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>countplot+hue+subplot</a></span></li><li><span><a href="#boxplot" data-toc-modified-id="boxplot-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>boxplot</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from datetime import date, timedelta

import matplotlib.pyplot as plt
#plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
import seaborn as sns
# %matplotlib inline

# %%
path = '/Users/ziyan/Documents/机器学习/机器学习比赛/favorita-grocery-sales-forecasting/'
train = pd.read_csv(path+"train.csv")
test = pd.read_csv(path+"test.csv")
transactions = pd.read_csv(path+"transactions.csv")
items = pd.read_csv(path+"items.csv")
stores = pd.read_csv(path+"stores.csv")
oil = pd.read_csv(path+"oil.csv")
holidays_events = pd.read_csv(path+"holidays_events.csv")
# Out:
# /var/folders/5n/0d0v__td7sd265lmdhjw1h440000gn/T/ipykernel_77540/2720580839.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(path+"train.csv")

# %% [markdown]
# ## 数据初探 nbr=number

# %% [markdown]
# ### train

# %%
train.head()
# Out:
#    id        date  store_nbr  item_nbr  unit_sales onpromotion
# 0   0  2013-01-01         25    103665         7.0         NaN
# 1   1  2013-01-01         25    105574         1.0         NaN
# 2   2  2013-01-01         25    105575         2.0         NaN
# 3   3  2013-01-01         25    108079         1.0         NaN
# 4   4  2013-01-01         25    108701         1.0         NaN

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125497040 entries, 0 to 125497039
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   item_nbr     int64
#  4   unit_sales   float64
#  5   onpromotion  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.6+ GB

# %%
train.describe()
# Out:
#                  id     store_nbr      item_nbr    unit_sales
# count  1.254970e+08  1.254970e+08  1.254970e+08  1.254970e+08
# mean   6.274852e+07  2.746458e+01  9.727692e+05  8.554865e+00
# std    3.622788e+07  1.633051e+01  5.205336e+05  2.360515e+01
# min    0.000000e+00  1.000000e+00  9.699500e+04 -1.537200e+04
# 25%    3.137426e+07  1.200000e+01  5.223830e+05  2.000000e+00
# 50%    6.274852e+07  2.800000e+01  9.595000e+05  4.000000e+00
# 75%    9.412278e+07  4.300000e+01  1.354380e+06  9.000000e+00
# max    1.254970e+08  5.400000e+01  2.127114e+06  8.944000e+04

# %%
stats = []
for col in train.columns:
    stats.append((col, train[col].nunique(), round(train[col].isnull().sum() * 100 / train.shape[0], 3), round(train[col].value_counts(normalize=True, dropna=False).values[0] * 100,3), train[col].dtype))
    
stats_df = pd.DataFrame(stats, columns=['特征', '属性个数', '缺失值占比', '最大属性占比', '特征类型'])
stats_df.sort_values('缺失值占比', ascending=False)[:10]
# Out:
#             特征       属性个数   缺失值占比  最大属性占比     特征类型
# 5  onpromotion          2  17.257  76.519   object
# 0           id  125497040   0.000   0.000    int64
# 1         date       1684   0.000   0.094   object
# 2    store_nbr         54   0.000   2.799    int64
# 3     item_nbr       4036   0.000   0.067    int64
# 4   unit_sales     258474   0.000  18.682  float64

# %% [markdown]
# ### test

# %%
test.head()
# Out:
#           id        date  store_nbr  item_nbr  onpromotion
# 0  125497040  2017-08-16          1     96995        False
# 1  125497041  2017-08-16          1     99197        False
# 2  125497042  2017-08-16          1    103501        False
# 3  125497043  2017-08-16          1    103520        False
# 4  125497044  2017-08-16          1    103665        False

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3370464 entries, 0 to 3370463
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   item_nbr     int64
#  4   onpromotion  bool
# dtypes: bool(1), int64(3), object(1)
# memory usage: 106.1+ MB

# %%
test.describe()
# Out:
#                  id     store_nbr      item_nbr
# count  3.370464e+06  3.370464e+06  3.370464e+06
# mean   1.271823e+08  2.750000e+01  1.244798e+06
# std    9.729693e+05  1.558579e+01  5.898362e+05
# min    1.254970e+08  1.000000e+00  9.699500e+04
# 25%    1.263397e+08  1.400000e+01  8.053210e+05
# 50%    1.271823e+08  2.750000e+01  1.294665e+06
# 75%    1.280249e+08  4.100000e+01  1.730015e+06
# max    1.288675e+08  5.400000e+01  2.134244e+06

# %%
stats = []
for col in test.columns:
    stats.append((col, test[col].nunique(), round(test[col].isnull().sum() * 100 / test.shape[0], 3), round(test[col].value_counts(normalize=True, dropna=False).values[0] * 100,3), test[col].dtype))
    
stats_df = pd.DataFrame(stats, columns=['特征', '属性个数', '缺失值占比', '最大属性占比', '特征类型'])
stats_df.sort_values('缺失值占比', ascending=False)[:10]
# Out:
#             特征     属性个数  缺失值占比  最大属性占比    特征类型
# 0           id  3370464    0.0   0.000   int64
# 1         date       16    0.0   6.250  object
# 2    store_nbr       54    0.0   1.852   int64
# 3     item_nbr     3901    0.0   0.026   int64
# 4  onpromotion        2    0.0  94.108    bool

# %% [markdown]
# ## 单变量分析（单变量的value_counts问题）

# %% [raw]
# 这一部分既有countplot也有barplot
# 当x不是unique的时候用countplot，反应x=？时，x的个数，因此参数只有x；
# 当x是unique的时候（一般是因为先使用了groupby=x）使用barplot，反应当x=？时，y的个数，因此参数有x和y

# %%
train["date"] =  pd.to_datetime(train["date"])
# train["year"] = train["date"].dt.year
train["month"] = train["date"].dt.month

# %%
train['item_nbr'].value_counts()
# Out:
# item_nbr
# 502331     83475
# 314384     83450
# 364606     83308
# 265559     83047
# 559870     82513
#            ...
# 2126944        5
# 2123747        3
# 2122818        2
# 2015898        1
# 2011451        1
# Name: count, Length: 4036, dtype: int64

# %%
plt.figure(figsize=(15,6))

# 绘制总计 unit sales
df_plot = train[train.date>=pd.Timestamp(2017,7,1)][train.item_nbr==502331].groupby(by=['date']).agg({'unit_sales':'sum'}).reset_index()
plt.plot(df_plot.date, df_plot.unit_sales)

# 设置 x 和 y 轴
plt.xlabel('Date',fontsize=14)
plt.ylabel('Unit Sales',fontsize=14)
plt.show()
#plt.savefig("12_date_sale_feature.svg", format="svg")
# Out:
# /var/folders/5n/0d0v__td7sd265lmdhjw1h440000gn/T/ipykernel_77540/3810010396.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_plot = train[train.date>=pd.Timestamp(2017,7,1)][train.item_nbr==502331].groupby(by=['date']).agg({'unit_sales':'sum'}).reset_index()

# %%
fig, ax = plt.subplots(1)
fig.autofmt_xdate()
fig.set_figheight(10)
fig.set_figwidth(16)

# 绘制总计 unit sales
df_plot = train.groupby(by=['date']).agg({'unit_sales':'sum'}).reset_index() #重新设置索引，原本index=date，现在index是1，2，3...
plt.plot(df_plot.date, df_plot.unit_sales)

# 绘制有促销的 unit sales
df_plot = train.loc[train['onpromotion'] == True].groupby(by=['date']).agg({'unit_sales':'sum'}).reset_index()
plt.plot(df_plot.date, df_plot.unit_sales)

# 绘制没有促销的 unit sales
df_plot = train.loc[train['onpromotion'] == False].groupby(by=['date']).agg({'unit_sales':'sum'}).reset_index()
plt.plot(df_plot.date, df_plot.unit_sales)

# 设置legend
plt.legend(['Total unit sales','On Promotion','Not On Promotion'], fontsize=14)

# 设置 x 和 y 轴
plt.xlabel('Date',fontsize=14)
plt.ylabel('Unit Sales',fontsize=14)
plt.show()
#plt.savefig("12_date_sale.svg", format="svg")

# %%
train['store_nbr'].value_counts().sort_index(ascending=True).plot(kind='bar') 
#画出来不好看，因此下面将使用seaborn
# Out:
# <Axes: xlabel='store_nbr'>

# %% [markdown]
# ### value_counts图countplot

# %%
sns.countplot?

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=train, x='store_nbr')#直接统计train['store_nbr']的value_counts
plt.xticks(rotation=75, fontsize=12)
plt.show()
#plt.savefig("12_store_nbr.svg", format="svg")

# %%
plt.figure(figsize=(15,6))

df_plot = train.groupby(by=['item_nbr']).agg({'id':'count'}).reset_index()
df_plot.columns = ['item_nbr', 'count']
plt.plot(df_plot['item_nbr'], df_plot['count'])

plt.xlabel('item_nbr',fontsize=14)
plt.ylabel('count',fontsize=14)
plt.show()
#看起来不够专业，下面用seaborn的barplot画一遍
#plt.savefig("12_item_nbr.svg", format="svg")

# %% [markdown]
# ### 均匀显示刻度

# %%
from matplotlib.ticker import MultipleLocator
plt.figure(figsize=(15,6))

df_plot = train.groupby(by=['item_nbr']).agg({'id':'count'}).reset_index()
df_plot.columns = ['item_nbr', 'count']

df_plot = df_plot.sort_values(by='item_nbr')

sns.barplot(data=df_plot, x='item_nbr', y='count')

plt.xlabel('item_nbr',fontsize=14)
plt.ylabel('count',fontsize=14)

x_major_locator = MultipleLocator(df_plot.shape[0] // 5)#此处最后的数字“5”为欲显示刻度数量，会均匀地显示5个刻度 //表示整除
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.show()
#plt.savefig("12_item_nbr.svg", format="svg")

# %% [markdown]
# ### value_counts图countplot

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=items, x='family')
plt.xticks(rotation=40, fontsize=8)
plt.xlabel('family',fontsize=14)
plt.ylabel('count',fontsize=14)
plt.show()
#plt.savefig("12_items_family.svg", format="svg")

# %% [markdown]
# ### barplot

# %%
df_plot.head()
# Out:
#        perishable  item_nbr
# 0  Non perishable      3114
# 1      Perishable       986

# %%
df_plot = items.fillna(-1).groupby(by=['perishable']).agg({'item_nbr':'count'}).reset_index()

df_plot.perishable = df_plot.perishable.replace({0:'Non perishable', 1:'Perishable', -1: 'Missing'})

plt.figure(figsize=(10,5))

sns.barplot(data=df_plot, x='perishable', y='item_nbr')

plt.xlabel('Is perishable', fontsize=14)
plt.ylabel('item_nbr count', fontsize=14)
plt.show()
#plt.savefig("12_items_perishable.svg", format="svg")

# %%
df_plot = stores.groupby('state').agg({'store_nbr':'count'}).reset_index()

plt.figure(figsize=(16,8))
sns.barplot(data=df_plot, x='state',y='store_nbr')

plt.xlabel('States',fontsize=14)
plt.ylabel('store count', fontsize=14)
plt.xticks(rotation=15, fontsize=8)
plt.show()
#plt.savefig("12_stores_state.svg", format="svg")

# %%
df_plot = stores.groupby('city').agg({'store_nbr':'count'}).reset_index()

plt.figure(figsize=(16,8))

sns.barplot(data=df_plot, x='city',y='store_nbr')

plt.xlabel('Cities',fontsize=14)
plt.ylabel('store count', fontsize=14)

plt.xticks(rotation=15, fontsize=8)
plt.show()
#plt.savefig("12_stores_city.svg", format="svg")

# %% [markdown]
# ## 多变量分析

# %%
df_plot = items.groupby(['family','perishable']).agg({'item_nbr':'count'}).reset_index()
plt.figure(figsize=(15,6))
sns.barplot(data=df_plot, y='item_nbr', x='family', hue='perishable')
plt.xticks(rotation=75, fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 df_plot = items.groupby(['family','perishable']).agg({'item_nbr':'count'}).reset_index()
#       2 plt.figure(figsize=(15,6))
# ----> 3 sns.barplot(data=df_plot, y='item_nbr', x='family', hue='perishable')
#       4 plt.xticks(rotation=75, fontsize=8)
#       5 plt.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'numpy.int64' object has no attribute 'startswith'

# %% [markdown]
# ### countplot+hue+subplot

# %%
#countplot+hue
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot(data=holidays_events, x='type', hue='locale')

plt.xlabel('Holiday EventType', fontsize=14)
plt.ylabel('Count of Holiday Events', fontsize=14)
plt.xticks(fontsize=9)
plt.title('countplot+hue')
#对比不加hue
plt.subplot(1,2,2)
sns.countplot(data=holidays_events, x='type')

plt.xlabel('Holiday EventType', fontsize=14)
plt.ylabel('Count of Holiday Events', fontsize=14)
plt.xticks(fontsize=9)
plt.title('countplot only')

plt.show()

# %%
df_plot = train.groupby('store_nbr').agg({'unit_sales':'sum'}).reset_index()

plt.figure(figsize=(16,8))
sns.barplot(data=df_plot, x='store_nbr',y='unit_sales')

plt.xlabel('store_nbr',fontsize=14)
plt.ylabel('Sum of unit_sales of store_nbr', fontsize=14)
plt.xticks(fontsize=12)
plt.show()
#plt.savefig("12_store_label.svg", format="svg")

# %% [markdown]
# ### boxplot

# %%
df_plot.head()
# Out:
#    item_nbr  unit_sales  idx
# 0     96995     10143.0    1
# 1     99197     17870.0    1
# 2    103501    164753.0    1
# 3    103520    201117.0    1
# 4    103665    219669.0    1

# %%
df_plot = train.groupby('item_nbr').agg({'unit_sales':'sum'}).reset_index()
df_plot['idx'] = 1
plt.figure(figsize=(16,8))
sns.boxplot(data=df_plot, x='idx',y='unit_sales')

plt.ylabel('Distribution of unit_sales of item_nbr', fontsize=14)
plt.xticks(fontsize=12)
plt.show()
#plt.savefig("12_item_label.svg", format="svg")

# %%
train = pd.merge(train, items, on='item_nbr', how='left')

# %%
df_plot = train.groupby(by=['date','perishable']).agg({'unit_sales':'sum'}).reset_index()
df_plot["date"] =  pd.to_datetime(df_plot["date"])

# %%
df_plot.head()
# Out:
#         date  perishable  unit_sales
# 0 2013-01-01           0    1879.655
# 1 2013-01-01           1     631.964
# 2 2013-01-02           0  378066.388
# 3 2013-01-02           1  118026.030
# 4 2013-01-03           0  274483.805

# %%
df_plot.loc[df_plot['perishable'] == True,'date'].head()
# Out:
# 1   2013-01-01
# 3   2013-01-02
# 5   2013-01-03
# 7   2013-01-04
# 9   2013-01-05
# Name: date, dtype: datetime64[ns]

# %%
fig, ax = plt.subplots(1)
fig.autofmt_xdate()
fig.set_figheight(10)
fig.set_figwidth(16)


plt.plot(df_plot.loc[df_plot['perishable'] == True,'date'], df_plot.loc[df_plot['perishable'] == True,'unit_sales'])

plt.plot(df_plot.loc[df_plot['perishable'] == False,'date'], df_plot.loc[df_plot['perishable'] == False,'unit_sales'])

# 设置legend
plt.legend(['Perishable','Non Perishable'], fontsize=14)

# 设置 x 和 y 轴
plt.xlabel('Date',fontsize=14)
plt.ylabel('Unit Sales',fontsize=14)
plt.show()
#plt.savefig("12_perishable_date_label.svg", format="svg")
